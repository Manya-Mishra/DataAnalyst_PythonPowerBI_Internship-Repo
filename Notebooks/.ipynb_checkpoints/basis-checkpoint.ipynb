# %% [markdown]
# # Data Analytics with Python & Power BI
# <hr>

# %% [markdown]
# ### Data Analysis is the process of collecting, cleaning, organizing, and examining data to find useful insights, patterns, trends, and support decision-making.<br> In simple words, Data analysis means turning raw data into meaningful information.
