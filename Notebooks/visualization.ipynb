# %% [markdown]
# # Module: Data Visualization
#
# ---
#
# # 1. What is Data Visualization?
#
# ## Definition
#
# Data Visualization is the graphical representation of data using charts, graphs, maps, and dashboards to communicate information clearly and efficiently.
#
# It helps identify:
# - Trends
# - Patterns
# - Relationships
# - Outliers
# - Business Insights
#
# ---
#
# ## Example
#
# ### Raw Data
#
# | Month | Sales |
# |---------|-------|
# | Jan | 50 |
# | Feb | 60 |
# | Mar | 75 |
# | Apr | 90 |
#
# Looking at the table, it's difficult to identify the trend.
#
# Using a **Line Chart**, we can immediately see that sales are increasing over time.
#
# ---
#
# # 2. Why is Data Visualization Important?
#
# ### Benefits
#
# - Simplifies complex data
# - Makes reports easier to understand
# - Helps in faster decision making
# - Detects trends
# - Identifies outliers
# - Finds hidden patterns
# - Improves communication with stakeholders
#
# ---
#
# # 3. Data Visualization Process
#
# Raw Data
#
# ↓
#
# Data Cleaning
#
# ↓
#
# Exploratory Data Analysis (EDA)
#
# ↓
#
# Choose Appropriate Chart
#
# ↓
#
# Generate Insights
#
# ↓
#
# Business Decisions
#
# ---
#
# # 4. Types of Data Visualization
#
# ## Comparison Charts
#
# Purpose:
# Compare categories.
#
# Examples:
# - Bar Chart
# - Column Chart
#
# ---
#
# ## Trend Charts
#
# Purpose:
# Show changes over time.
#
# Examples:
# - Line Chart
# - Area Chart
#
# ---
#
# ## Composition Charts
#
# Purpose:
# Show parts of a whole.
#
# Examples:
# - Pie Chart
# - Donut Chart
# - Stacked Bar Chart
#
# ---
#
# ## Distribution Charts
#
# Purpose:
# Understand data distribution.
#
# Examples:
# - Histogram
# - Box Plot
# - Violin Plot
#
# ---
#
# ## Relationship Charts
#
# Purpose:
# Show relationships between variables.
#
# Examples:
# - Scatter Plot
# - Bubble Chart
# - Heatmap
#
# ---
#
# # 5. Types of Charts
#
# - Bar Chart
# - Column Chart
# - Line Chart
# - Area Chart
# - Pie Chart
# - Donut Chart
# - Scatter Plot
# - Bubble Chart
# - Histogram
# - Box Plot
# - Violin Plot
# - Heatmap
# - Count Plot
# - Pair Plot
# - Treemap
# - Waterfall Chart
# - Funnel Chart
# - Radar Chart
# - Gauge Chart
# - Sankey Diagram
# - Gantt Chart
# - Choropleth Map
# - Word Cloud
#
# ---
#
# # 6. When to Use Which Chart
#
# (Refer to the detailed chart selection guide.)
#
# ---
#
# # 7. Comparison of Similar Charts
#
# ## Bar Chart vs Histogram
#
# | Bar Chart | Histogram |
# |------------|-----------|
# | Categorical Data | Continuous Data |
# | Gaps between bars | No gaps |
# | Compare categories | Show distribution |
#
# ---
#
# ## Pie Chart vs Donut Chart
#
# | Pie | Donut |
# |------|--------|
# | Simpler | Better for dashboards |
# | Hard with many categories | Can display total in center |
#
# ---
#
# ## Scatter Plot vs Bubble Chart
#
# | Scatter | Bubble |
# |----------|--------|
# | Two variables | Three variables |
# | Equal point size | Bubble size represents third variable |
#
# ---
#
# ## Area Chart vs Line Chart
#
# | Line | Area |
# |------|------|
# | Focus on trend | Focus on trend + magnitude |
#
# ---
#
# # 8. Color Best Practices
#
# ### Use
#
# - Blue → Neutral
# - Green → Positive
# - Red → Negative
# - Orange → Warning
#
# Avoid
#
# - Too many colors
# - Neon colors
# - Similar shades
#
# ---
#
# # 9. Visualization Best Practices
#
# ✔ Keep charts simple
#
# ✔ Label axes
#
# ✔ Add chart title
#
# ✔ Mention units
#
# ✔ Highlight key insights
#
# ✔ Maintain consistent colors
#
# ✔ Sort categories when needed
#
# ✔ Avoid unnecessary 3D effects
#
# ✔ Use readable fonts
#
# ✔ Avoid clutter
#
# ---
#
# # 10. Common Visualization Mistakes
#
# ❌ Wrong chart selection
#
# ❌ Too many colors
#
# ❌ Missing labels
#
# ❌ Overcrowded charts
#
# ❌ Distorted axes
#
# ❌ Unnecessary 3D charts
#
# ❌ Pie chart with many categories
#
# ❌ Tiny fonts
#
# ❌ Misleading scales
#
# ---
#
# # 11. Choosing the Right Chart
#
# | Objective | Recommended Chart |
# |------------|-------------------|
# | Compare categories | Bar Chart |
# | Compare values over time | Line Chart |
# | Distribution | Histogram |
# | Detect outliers | Box Plot |
# | Relationship | Scatter Plot |
# | Correlation | Heatmap |
# | Percentage | Pie Chart |
# | Ranking | Horizontal Bar Chart |
# | Geographic Analysis | Map |
# | Process Flow | Sankey Diagram |
#
# ---
#
# # 12. Data Visualization Libraries in Python
#
# ## Matplotlib
#
# - Basic plotting library
# - Highly customizable
# - Foundation for many libraries
#
# Example
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.plot(x, y)
# plt.show()
# ```
#
# ---
#
# ## Seaborn
#
# - Built on Matplotlib
# - Better statistical graphics
# - Attractive default themes
#
# Example
#
# ```python
# import seaborn as sns
#
# sns.scatterplot(data=df, x="Age", y="Salary")
# ```
#
# ---
#
# ## Plotly
#
# - Interactive charts
# - Zoom and hover support
# - Dashboards
#
# ---
#
# ## Bokeh
#
# Interactive web visualizations.
#
# ---
#
# ## Altair
#
# Declarative statistical visualization library.
#
# ---
#
# ## Power BI
#
# Business Intelligence tool for interactive dashboards.
#
# ---
#
# ## Tableau
#
# Popular Business Intelligence and visualization software.
#
# ---
#
# # 13. Dashboard Design Principles
#
# A good dashboard should answer business questions quickly.
#
# ### Characteristics
#
# - Clear layout
# - Logical grouping
# - Interactive filters
# - KPI cards
# - Consistent colors
# - Responsive design
#
# ---
#
# # 14. KPI Cards
#
# KPIs summarize important business metrics.
#
# Example
#
# - Total Revenue
# - Total Orders
# - Average Order Value
# - Profit
# - Customer Count
#
# ---
#
# # 15. Storytelling with Data
#
# Good dashboards should tell a story.
#
# Example
#
# Business Question
#
# ↓
#
# Sales dropped
#
# ↓
#
# Find affected region
#
# ↓
#
# Analyze products
#
# ↓
#
# Identify cause
#
# ↓
#
# Recommend solution
#
# ---
#
# # 16. Real Business Examples
#
# ## Sales Dashboard
#
# Charts
#
# - KPI Cards
# - Monthly Sales Line Chart
# - Product-wise Revenue Bar Chart
# - Region-wise Sales Map
# - Top Customers Table
#
# ---
#
# ## HR Dashboard
#
# Charts
#
# - Employee Count
# - Department Distribution
# - Salary Histogram
# - Attrition Rate Gauge
# - Gender Pie Chart
#
# ---
#
# ## E-commerce Dashboard
#
# Charts
#
# - Revenue Trend
# - Orders by Category
# - Top Products
# - Customer Segmentation
# - Payment Method Distribution
#
# ---
#
# ## Healthcare Dashboard
#
# Charts
#
# - Patients per Department
# - Disease Distribution
# - Recovery Rate
# - Age Distribution Histogram
#
# ---
#
# # 17. Interview Questions
#
# ### Q1. Why is visualization important?
#
# Visualization helps identify patterns, trends, and insights quickly, making data easier to understand and supporting better decision-making.
#
# ---
#
# ### Q2. Which chart is best for monthly sales?
#
# **Answer:** Line Chart.
#
# ---
#
# ### Q3. Which chart is best for comparing products?
#
# **Answer:** Bar Chart.
#
# ---
#
# ### Q4. Which chart detects outliers?
#
# **Answer:** Box Plot.
#
# ---
#
# ### Q5. Which chart shows correlation?
#
# **Answer:** Scatter Plot or Heatmap.
#
# ---
#
# ### Q6. Which library is commonly used for statistical visualization in Python?
#
# **Answer:** Seaborn.
#
# ---
#
# ### Q7. Which BI tools are popular in the industry?
#
# **Answer:** Power BI and Tableau.
#
# ---
#
# # 18. Mini Case Study
#
# ### Business Problem
#
# An online retail company wants to improve sales.
#
# ### Data Collected
#
# - Monthly Revenue
# - Product Category
# - Customer Region
# - Profit
# - Order Count
#
# ### Visualizations Used
#
# - KPI Cards → Total Revenue, Total Profit
# - Line Chart → Monthly Revenue Trend
# - Bar Chart → Sales by Category
# - Pie Chart → Region-wise Revenue Share
# - Heatmap → Correlation Between Revenue and Profit
# - Box Plot → Detect Outliers in Order Value
#
# ### Insights
#
# - Sales peak during festive months.
# - Electronics generate the highest revenue.
# - West region contributes the largest share.
# - A few orders have unusually high values (outliers).
#
# ### Business Recommendation
#
# Increase inventory before festive seasons, focus marketing on high-performing categories, and investigate unusually large orders.

# %% [markdown]
# # Choosing the Right Chart in Data Analysis
#
# One of the most important skills of a Data Analyst is selecting the appropriate chart. Choosing the wrong chart can make insights difficult to understand or even misleading.
#
# ---
#
# # Quick Decision Guide
#
# | If you want to... | Use This Chart |
# |-------------------|---------------|
# | Compare categories | Bar Chart |
# | Show trends over time | Line Chart |
# | Show percentage/share | Pie Chart |
# | Show relationship between two numerical variables | Scatter Plot |
# | Show data distribution | Histogram |
# | Detect outliers | Box Plot |
# | Compare distributions | Box Plot / Violin Plot |
# | Compare parts of a whole over time | Stacked Bar Chart |
# | Show correlation between many variables | Heatmap |
# | Compare values across two categories | Grouped Bar Chart |
# | Show cumulative total | Area Chart |
# | Display exact values | Table |
#
# ---
#
# # 1. Bar Chart
#
# ## Purpose
#
# Compare values across different categories.
#
# ## Best For
#
# - Sales by Product
# - Revenue by City
# - Students in Each Department
# - Number of Employees per Department
#
# ## Example Dataset
#
# | Product | Sales |
# |----------|------:|
# | Laptop | 500 |
# | Mobile | 800 |
# | Tablet | 300 |
# | Printer | 200 |
#
# ### Best Chart
#
# **Bar Chart**
#
# Reason:
# Each product is a different category.
#
# ### Pandas
#
# ```python
# df.plot(
#     x="Product",
#     y="Sales",
#     kind="bar"
# )
# ```
#
# ---
#
# # 2. Line Chart
#
# ## Purpose
#
# Show trends over time.
#
# ## Best For
#
# - Monthly Sales
# - Daily Temperature
# - Stock Prices
# - AQI Trends
#
# ## Example
#
# | Month | Revenue |
# |-------|---------:|
# | Jan | 50 |
# | Feb | 60 |
# | Mar | 75 |
# | Apr | 80 |
#
# ### Best Chart
#
# **Line Chart**
#
# Reason:
# Months follow chronological order.
#
# ### Pandas
#
# ```python
# df.plot(
#     x="Month",
#     y="Revenue",
#     kind="line"
# )
# ```
#
# ---
#
# # 3. Pie Chart
#
# ## Purpose
#
# Show percentage contribution of each category to the whole.
#
# ## Best For
#
# - Market Share
# - Budget Allocation
# - Revenue Contribution
# - Gender Distribution
#
# ## Example
#
# | Category | Revenue |
# |----------|---------:|
# | Electronics | 45 |
# | Clothing | 30 |
# | Grocery | 25 |
#
# ### Best Chart
#
# **Pie Chart**
#
# Reason:
# The categories together make up 100%.
#
# ### Pandas
#
# ```python
# df.plot(
#     y="Revenue",
#     kind="pie",
#     labels=df["Category"],
#     autopct="%1.1f%%"
# )
# ```
#
# ### Avoid Pie Charts When
#
# - More than 5–6 categories
# - Comparing exact values
# - Showing trends over time
#
# ---
#
# # 4. Scatter Plot
#
# ## Purpose
#
# Show the relationship (correlation) between two numerical variables.
#
# ## Best For
#
# - Height vs Weight
# - Study Hours vs Marks
# - Advertising Cost vs Sales
# - Experience vs Salary
#
# ## Example
#
# | Study Hours | Marks |
# |-------------|-------:|
# | 2 | 55 |
# | 4 | 70 |
# | 6 | 82 |
# | 8 | 95 |
#
# ### Best Chart
#
# **Scatter Plot**
#
# Reason:
# Both variables are numerical.
#
# ### Pandas
#
# ```python
# df.plot(
#     x="Study Hours",
#     y="Marks",
#     kind="scatter"
# )
# ```
#
# ---
#
# # 5. Histogram
#
# ## Purpose
#
# Understand data distribution.
#
# ## Best For
#
# - Age Distribution
# - Salary Distribution
# - Marks Distribution
#
# ## Example
#
# Employee Salaries
#
# ```
# 25000
# 28000
# 30000
# 32000
# 35000
# 42000
# 50000
# 55000
# ```
#
# ### Best Chart
#
# **Histogram**
#
# Reason:
# Shows how frequently values fall into ranges (bins).
#
# ### Pandas
#
# ```python
# df["Salary"].plot(
#     kind="hist",
#     bins=10
# )
# ```
#
# ---
#
# # 6. Box Plot
#
# ## Purpose
#
# Identify outliers and understand spread.
#
# ## Best For
#
# - Salary Analysis
# - Marks Analysis
# - Customer Spending
#
# ## Example
#
# ```
# 20
# 25
# 24
# 27
# 28
# 26
# 29
# 95
# ```
#
# ### Best Chart
#
# **Box Plot**
#
# Reason:
# 95 is an outlier.
#
# ### Pandas
#
# ```python
# df.boxplot(column="Salary")
# ```
#
# ---
#
# # 7. Heatmap
#
# ## Purpose
#
# Visualize correlation between variables.
#
# ## Best For
#
# - Feature Correlation
# - EDA
# - Machine Learning
#
# ## Example
#
# | | Age | Salary | Experience |
# |---|----:|-------:|-----------:|
# | Age | 1.0 | 0.72 | 0.84 |
# | Salary | 0.72 | 1.0 | 0.91 |
# | Experience | 0.84 | 0.91 | 1.0 |
#
# ### Best Chart
#
# **Heatmap**
#
# Reason:
# Shows strong and weak correlations using colors.
#
# ### Seaborn
#
# ```python
# import seaborn as sns
#
# sns.heatmap(
#     df.corr(numeric_only=True),
#     annot=True
# )
# ```
#
# ---
#
# # 8. Area Chart
#
# ## Purpose
#
# Show cumulative totals over time.
#
# ## Best For
#
# - Revenue Growth
# - Website Traffic
# - Population Growth
#
# ### Example
#
# Monthly website visitors.
#
# ### Pandas
#
# ```python
# df.plot(
#     x="Month",
#     y="Visitors",
#     kind="area"
# )
# ```
#
# ---
#
# # 9. Grouped Bar Chart
#
# ## Purpose
#
# Compare multiple categories together.
#
# ## Best For
#
# - Sales by Product and Year
# - Student Performance by Class
# - Revenue by Region and Quarter
#
# ## Example
#
# | Product | 2024 | 2025 |
# |----------|-----:|-----:|
# | Laptop | 50 | 65 |
# | Mobile | 70 | 90 |
#
# ### Best Chart
#
# Grouped Bar Chart
#
# ---
#
# # 10. Stacked Bar Chart
#
# ## Purpose
#
# Show composition within categories.
#
# ## Best For
#
# - Sales by Region
# - Budget Breakdown
# - Population by Age Groups
#
# ---
#
# # 11. Count Plot
#
# ## Purpose
#
# Count occurrences of categorical values.
#
# ## Best For
#
# - Gender Distribution
# - Department Count
# - Customer Categories
#
# ### Example
#
# | Department |
# |------------|
# | IT |
# | HR |
# | IT |
# | Finance |
# | IT |
#
# ### Seaborn
#
# ```python
# sns.countplot(
#     x="Department",
#     data=df
# )
# ```
#
# ---
#
# # 12. Pair Plot
#
# ## Purpose
#
# Visualize relationships among multiple numerical variables.
#
# ## Best For
#
# - Exploratory Data Analysis (EDA)
# - Machine Learning
#
# ### Seaborn
#
# ```python
# sns.pairplot(df)
# ```
#
# ---
#
# # 13. Violin Plot
#
# ## Purpose
#
# Compare distributions while showing density.
#
# ## Best For
#
# - Salary by Department
# - Marks by Class
# - Age by Gender
#
# ### Seaborn
#
# ```python
# sns.violinplot(
#     x="Department",
#     y="Salary",
#     data=df
# )
# ```
#
# ---
#
# # Real-World Examples
#
# | Business Problem | Recommended Chart | Reason |
# |------------------|------------------|--------|
# | Monthly Sales Trend | Line Chart | Shows change over time |
# | Top 10 Products | Bar Chart | Easy comparison of categories |
# | Market Share | Pie Chart | Shows percentage contribution |
# | Salary Distribution | Histogram | Displays frequency distribution |
# | Salary Outliers | Box Plot | Detects unusual values |
# | Ad Spend vs Sales | Scatter Plot | Shows correlation |
# | Customer Churn by Gender | Count Plot | Counts categorical values |
# | Correlation Between Features | Heatmap | Highlights relationships |
# | Revenue by Product and Year | Grouped Bar Chart | Compares two dimensions |
# | Budget Allocation | Stacked Bar Chart | Shows composition within totals |
#
# ---
#
# # Interview Tip
#
# ### Q. How do you choose the right chart?
#
# **Answer:**
#
# - **Bar Chart:** Compare categories.
# - **Line Chart:** Show trends over time.
# - **Pie Chart:** Show parts of a whole (few categories).
# - **Scatter Plot:** Show relationships between two numerical variables.
# - **Histogram:** Show data distribution.
# - **Box Plot:** Detect outliers and compare distributions.
# - **Heatmap:** Show correlation between variables.
# - **Stacked/Grouped Bar Chart:** Compare multiple categories or show composition.

# %% [markdown]
# ![CHARTS-GUIDE](attachment:{B2B930BD-153A-456D-873B-96C70F2DBFC3}.png)
