# %% [markdown]
# # Data Analytics with Python & Power BI
# <hr>

# %% [markdown]
# ## What is Data Analysis?

# %% [markdown]
# ### Data Analysis is the process of collecting, cleaning, transforming, and interpreting data to discover useful insights, identify patterns, and support decision-making.<br> In simple words, Data analysis means turning raw data into meaningful insights.

# %% [markdown]
# Example
#
# A retail company has sales data for the last year.
#
# A Data Analyst can:
#
# Identify the best-selling products
# Find peak sales months
# Analyze customer purchasing behavior
# Recommend strategies to increase revenue

# %% [markdown]
# ## Why is Data Analysis Important?
#
# Organizations generate huge amounts of data every day. Data analysis helps them make informed decisions instead of relying on assumptions.
#
# Benefits -
# <br>Better business decisions
# <br>Improved efficiency
# <br>Cost reduction
# <br>Increased revenue
# <br>Customer understanding
# <br>Risk management
# <br>Trend identification
#
# <br>Example
# <br>Netflix analyzes user viewing patterns to recommend movies and shows.

# %% [markdown]
# ## Real-World Applications of Data Analysis
# ### Business
# * Sales forecasting
# * Revenue analysis
# * Market trend analysis
# ### Healthcare
# * Disease prediction
# * Patient monitoring
# ### Banking
# * Fraud detection
# * Credit risk assessment
# ### E-commerce
# * Product recommendations
# * Customer segmentation
# ### Education
# * Student performance analysis
# * Learning outcome improvement
# ### Transportation
# * Route optimization
# * Traffic prediction

# %% [markdown]
# ## Data-Driven Decision Making
# Definition
#
# Data-driven decision making (DDDM) refers to making decisions based on analyzed data rather than intuition or guesswork.
#
# Traditional Approach
#
# "Sales seem low this month."
#
# Data-Driven Approach
#
# "Sales decreased by 12% because customer purchases dropped in the North region."
#
# Advantages
# * Higher accuracy
# * Reduced uncertainty
# * Better business outcomes
# * Objective decision-making

# %% [markdown]
# Example 1: Restaurant
#
# ❌ Guess-Based Decision
# "We think customers like Pizza."
#
# ✅ Data-Driven Decision
# "Pizza contributes 35% of total revenue and has the highest repeat orders."

# %% [markdown]
# Example 2: Online Learning Platform
#
# ❌ Guess-Based Decision
# "Students probably like video lectures."
#
# ✅ Data-Driven Decision
# "Students spend 70% more time on video lessons than text lessons."

# %% [markdown]
# ## Data Analysis Lifecycle
#
# The Data Analysis Lifecycle describes the step-by-step process followed by analysts to solve business problems using data.

# %% [markdown]
# ### Step 1: Business Understanding
#
# Purpose
# <br>Understand the problem before analyzing data.
#
# Questions to Ask
# * What is the business problem?
# * What are the goals?
# * What decisions need to be made?

# %% [markdown]
# Example 1 -
# <br>A telecom company wants to reduce customer churn.
#
# Problem:
# <br><b>"Why are customers leaving the service?"

# %% [markdown]
# Example 2 -
# <br>Gym Membership
#
# Problem:
# <br><b>Many members stop coming after 3 months.</b>
#
# Business Question:
# <br><b>Why are members leaving?</b>
#
# Goal:
# <br><b>Increase member retention.</b>

# %% [markdown]
# ### Step 2: Data Collection
# Purpose
# <br>Gather relevant data from different sources.
#
# Sources
# * Databases
# * Excel files
# * APIs
# * Surveys
# * Websites
# * IoT devices
#
# Example -
# <br>Telecom Company
#
# Collected Data:
# <b>
# * Customer age
# * Recharge amount
# * Call duration
# * Complaint history
# </b>

# %% [markdown]
# ### Step 3: Data Cleaning
# Purpose
#
# Prepare data for analysis.
#
# Common Issues
# * Missing values
# * Duplicate records
# * Incorrect data types
# * Inconsistent formats
# * Outliers
# Example
#
# <b>Before Cleaning</b>
#
# | Customer_ID | Age |
# |------------|----:|
# | 101 | 25 |
# | 102 | Null |
#
# <b>After Cleaning</b>
#
# | Customer_ID | Age |
# |------------|----:|
# | 101 | 25 |
# | 102 | 24 |
#
# <br>
# Example - <br>
#
# <b>Raw Data</b>
#
# | Customer_ID | Age |
# |------------|----:|
# | A101 | 25 |
# | A102 | NULL |
# | A103 | 25 |
# | A103 | 25 |
#
#
# Problems:
# - Missing Value
# - Duplicate Record
#
# After Cleaning:
# - Missing age filled
# - Duplicate removed
#
# | Customer_ID | Age |
# |------------|----:|
# | A101 | 25 |
# | A102 | 25 *(Filled with Mean)* |
# | A103 | 25 |

# %% [markdown]
# ### Step 4: Data Exploration
# Purpose
# Understand the characteristics of data.
#
# Activities
# <b>
# - Summary statistics
# - Distribution analysis
# - Correlation analysis
# - Pattern identification
# </b>
#
# Example -
#
# Find:
# <br>Average customer age
# <br>Most purchased products
# <br>Monthly sales trends
#
# Lets take, Sales Dataset ::
#
# Questions:
#
# - Which city generates the highest sales?
# - Which month has maximum revenue?
# - Which product category is most profitable?
#
# So, Insights:
#
# - Delhi contributes 30% of sales.
# - December has highest revenue.
